# %%
import pandas as pd
import numpy as np

import warnings 
warnings.filterwarnings("ignore")


import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path=r"C:\Users\shiva\Downloads\Sensor_project\notebooks\wafer_23012020_041211.csv"
wafers=pd.read_csv(file_path)
print("shape of the feture store dataset: ",wafers.shape)
wafers.head()
# Out:
# shape of the feture store dataset:  (100, 592)
#   Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2  Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3  Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4  Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2  101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3  101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4  104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
#
# ...

# %%
wafers.isnull().sum()
# Out:
# Unnamed: 0    0
# Sensor-1      1
# Sensor-2      0
# Sensor-3      3
# Sensor-4      3
#              ..
# Sensor-587    0
# Sensor-588    0
# Sensor-589    0
# Sensor-590    0
# Good/Bad      0
# Length: 592, dtype: int64

# %%
wafers.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=592)

# %%
wafers.columns.dtype
# Out:
# dtype('O')

# %%
wafers.rename(columns={"Unnamed: 0": "Wafer"}, inplace=True)  # Add a space between Unnamed and 0 if necessary

# %%
wafers.head()
# Out:
#        Wafer  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2  Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3  Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4  Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2  101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3  101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4  104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
#
# ...

# %%
from sklearn.model_selection import train_test_split
wafers,wafers_test=train_test_split(wafers,test_size=0.20,random_state=42)

# %%
wafers.shape
# Out:
# (80, 592)

# %%
wafers_test.shape
# Out:
# (20, 592)

# %%
wafers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, 55 to 51
# Columns: 592 entries, Wafer to Good/Bad
# dtypes: float64(494), int64(97), object(1)
# memory usage: 370.6+ KB

# %%
wafers.describe()
# Out:
#           Sensor-1     Sensor-2     Sensor-3     Sensor-4   Sensor-5  \
# count    79.000000    80.000000    78.000000    78.000000  78.000000
# mean   3019.048228  2494.058875  2202.758988  1519.467071   1.201382
# std      72.665372    68.166898    31.633772   471.962104   0.365870
# min    2889.670000  2254.990000  2114.666700   978.783200   0.753100
# 25%    2975.425000  2452.517500  2189.966700  1111.543600   0.850075
# 50%    3004.390000  2502.445000  2200.955600  1308.647900   1.164250
# 75%    3065.730000  2532.755000  2212.866700  1997.641600   1.383000
# max    3221.210000  2664.520000  2315.266700  2363.641200   2.207300
#
#        Sensor-6    Sensor-7   Sensor-8   Sensor-9  Sensor-10  ...  Sensor-582  \
# count      78.0   78.000000  78.000000  80.000000  80.000000  ...   27.000000
# mean      100.0   96.881160   0.122158   1.460087   0.000946  ...   63.785093
# std         0.0    5.520108   0.002062   0.072159   0.010865  ...   30.722790
# ...

# %%
wafers["Good/Bad"].value_counts()
# Out:
# Good/Bad
# -1    74
#  1     6
# Name: count, dtype: int64

# %% [markdown]
# ## this is the highly imbalanced dataset

# %%
wafers["Good/Bad"].isna().sum()
#check miss values in target
# Out:
# 0

# %% [markdown]
# woa,not a single missing data in the target

# %%
wafers.isna().sum().sum()
##overall the missing data
# Out:
# 1822

# %%
# check missing values in dependent feature variables

wafers.isna().sum().sum()/(wafers.shape[0]*(wafers.shape[1])-1)
# Out:
# 0.03847209611689436

# %%
random_50_sensors_idx=[]
for i in range(50):
    if i not in random_50_sensors_idx:
        random_50_sensors_idx.append(np.random.randint(1,591))

# %%
plt.figure(figsize=(15,100))

for i,col in enumerate(wafers.columns[random_50_sensors_idx]):
    plt.subplot(60,3,i+1)
    sns.displot(x=wafers[col],color='indianred')
    plt.xlabel(col,weight="bold")
    plt.tight_layout()

# %% [markdown]
# #get columns to drop

# %%
# def get_cols_with_zero_std_dev(df:pd.DataFrame):
#     """
#     Returns a list of columns names who are having zero standard deviation.
#     """

#     cols_to_drop=[]
#     num_cols=[col for col in df.columns if df[col].dtype!='O']#numericals only
#     for col in num_cols:
#         if df[col].std()==0:
#             cols_to_drop.append(col)
#     return cols_to_drop


# import pandas as pd

# def get_redundant_cols(df: pd.DataFrame, missing_thresh: float = 0.7):
#     """
#     Return a list of columns having missing values more than a certain threshold.
#     """
#     # Calculate the ratio of missing values for each column
#     cols_missing_ratios = df.isna().sum().div(df.shape[0])
    
#     # Identify columns with missing values ratio greater than the threshold
#     cols_to_drop = cols_missing_ratios[cols_missing_ratios > missing_thresh].index.tolist()
    
#     return cols_to_drop




# ## seprate feature and labesls out


# X,y=wafers.drop(cols_to_drop,axis=1),wafers[["Good/Bad"]]




import pandas as pd

def get_cols_with_zero_std_dev(df: pd.DataFrame):
    """
    Returns a list of column names with zero standard deviation.
    """
    cols_to_drop = []
    num_cols = [col for col in df.columns if df[col].dtype != 'O']  # Numerical columns only
    for col in num_cols:
        if df[col].std() == 0:
            cols_to_drop.append(col)
    return cols_to_drop

def get_redundant_cols(df: pd.DataFrame, missing_thresh: float = 0.7):
    """
    Return a list of columns having missing values more than a certain threshold.
    """
    # Calculate the ratio of missing values for each column
    cols_missing_ratios = df.isna().sum().div(df.shape[0])
    
    # Identify columns with missing values ratio greater than the threshold
    cols_to_drop = cols_missing_ratios[cols_missing_ratios > missing_thresh].index.tolist()
    
    return cols_to_drop

# Example usage:
# Assuming `wafers` is your DataFrame
cols_zero_std_dev = get_cols_with_zero_std_dev(wafers)
cols_redundant = get_redundant_cols(wafers, missing_thresh=0.7)

# Combine lists and remove duplicates
cols_to_drop = list(set(cols_zero_std_dev + cols_redundant))

# Separate features and labels
X = wafers.drop(columns=cols_to_drop)
y = wafers[["Good/Bad"]]

# %%
wafers.dtypes
# Out:
# Wafer          object
# Sensor-1      float64
# Sensor-2      float64
# Sensor-3      float64
# Sensor-4      float64
#                ...
# Sensor-587    float64
# Sensor-588    float64
# Sensor-589    float64
# Sensor-590    float64
# Good/Bad        int64
# Length: 592, dtype: object

# %%
# Example DataFrame
# wafers = pd.DataFrame(...)  # Your DataFrame definition goes here

# Call the function with the DataFrame
cols_to_drop_1 = get_redundant_cols(wafers, missing_thresh=0.7)
print(cols_to_drop_1)
# Out:
# ['Sensor-158', 'Sensor-159', 'Sensor-293', 'Sensor-294']

# %%
## cols w 0 standard deviation

cols_to_drop_2=get_cols_with_zero_std_dev(df=wafers)
cols_to_drop_2.append("Wafer")
cols_to_drop_2
# Out:
# ['Sensor-6',
#  'Sensor-14',
#  'Sensor-43',
#  'Sensor-50',
#  'Sensor-53',
#  'Sensor-70',
#  'Sensor-75',
#  'Sensor-98',
#  'Sensor-142',
#  'Sensor-150',
#  'Sensor-179',
#  'Sensor-180',
#  'Sensor-187',
#  'Sensor-190',
#  'Sensor-191',
#  'Sensor-192',
#  'Sensor-193',
#  'Sensor-194',
#  'Sensor-195',
#  'Sensor-207',
#  'Sensor-210',
#  'Sensor-227',
#  'Sensor-230',
#  'Sensor-231',
#  'Sensor-232',
#  'Sensor-233',
#  'Sensor-234',
#  'Sensor-235',
#  'Sensor-236',
#  'Sensor-237',
#  'Sensor-238',
#  'Sensor-241',
#  'Sensor-242',
#  'Sensor-243',
#  'Sensor-244',
#  'Sensor-257',
#  'Sensor-258',
#  'Sensor-259',
#  'Sensor-260',
#  'Sensor-261',
#  'Sensor-262',
#  'Sensor-263',
#  'Sensor-264',
#  'Sensor-265',
#  'Sensor-266',
#  'Sensor-267',
#  'Sensor-277',
#  'Sensor-285',
#  'Sensor-314',
#  'Sensor-315',
#  'Sensor-316',
#  'Sensor-323',
#  'Sensor-326',
#  'Sensor-327',
#  'Sensor-328',
#  'Sensor-329',
#  'Sensor-330',
#  'Sensor-331',
#  'Sensor-343',
# ...

# %%
X
# Out:
#         Wafer  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-7  \
# 55  Wafer-856       NaN   2532.45  2191.1333  2197.6570    1.1569   89.7222
# 88  Wafer-889   3221.21   2391.20  2189.9667  1046.6212    0.8662  102.3622
# 26  Wafer-827   2951.85   2525.00  2189.5777  1320.3197    1.3459  100.7744
# 42  Wafer-843   2982.07   2447.06  2199.6334  1242.8420    1.4083   99.2178
# 69  Wafer-870   3058.08   2524.60  2192.3778  1110.5453    0.8147   99.2922
# ..        ...       ...       ...        ...        ...       ...       ...
# 60  Wafer-861   3071.05   2642.15  2200.9889  1054.5240    1.3830  100.1800
# 71  Wafer-872   3043.18   2545.53  2192.3778  1110.5453    0.8147   99.2922
# 14  Wafer-815   3001.26   2519.92  2224.6778  1308.6479    1.3907  101.1333
# 92  Wafer-893   3007.00   2572.62  2213.2111  2070.7147    1.9705   87.7411
# 51  Wafer-852   3078.77   2533.04  2187.4111  1942.3069    1.1864   88.0911
#
# ...

# %%
y
# Out:
#     Good/Bad
# 55        -1
# 88        -1
# 26        -1
# 42        -1
# 69        -1
# ..       ...
# 60        -1
# 71        -1
# 14        -1
# 92        -1
# 51        -1
#
# [80 rows x 1 columns]

# %%
##dependent feature variables

print("Shape of the feature now :",X.shape)
X.head
# Out:
# Shape of the feature now : (80, 466)
# <bound method NDFrame.head of         Wafer  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-7  \
# 55  Wafer-856       NaN   2532.45  2191.1333  2197.6570    1.1569   89.7222
# 88  Wafer-889   3221.21   2391.20  2189.9667  1046.6212    0.8662  102.3622
# 26  Wafer-827   2951.85   2525.00  2189.5777  1320.3197    1.3459  100.7744
# 42  Wafer-843   2982.07   2447.06  2199.6334  1242.8420    1.4083   99.2178
# 69  Wafer-870   3058.08   2524.60  2192.3778  1110.5453    0.8147   99.2922
# ..        ...       ...       ...        ...        ...       ...       ...
# 60  Wafer-861   3071.05   2642.15  2200.9889  1054.5240    1.3830  100.1800
# 71  Wafer-872   3043.18   2545.53  2192.3778  1110.5453    0.8147   99.2922
# 14  Wafer-815   3001.26   2519.92  2224.6778  1308.6479    1.3907  101.1333
# 92  Wafer-893   3007.00   2572.62  2213.2111  2070.7147    1.9705   87.7411
# ...

# %%
##INDEPENDENT / TARGET VARIABLES
print("Shape of labels:",y.shape)
y.head()
# Out:
# Shape of labels: (80, 1)
#     Good/Bad
# 55        -1
# 88        -1
# 26        -1
# 42        -1
# 69        -1

# %% [markdown]
# # DATA Transformation

# %%
# from sklearn.pipeline import Pipeline
# from sklearn.impute import  KNNImputer
# from sklearn.impute import  SimpleImputer
# from sklearn.preprocessing import  RobustScaler
# ### from sklearn.preprocessing import StandardScaler

# imputer=KNNImputer(n_neighbors=3)
# preprocessing_pipeline=Pipeline(
#     steps=[('Imputer',imputer),('Scaler',RobustScaler())])


# preprocessing_pipeline



import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.preprocessing import RobustScaler

# Define the pipeline with KNNImputer and RobustScaler
imputer = KNNImputer(n_neighbors=3)
preprocessing_pipeline = Pipeline(
    steps=[
        ('Imputer', imputer),
        ('Scaler', RobustScaler())
    ]
)

# Select only numerical columns from X
X_numeric = X.select_dtypes(include=['number'])

# Transform the numerical features
X_trans = preprocessing_pipeline.fit_transform(X_numeric)

print("Shape of transformed features set:", X_trans.shape)

# Display the transformed features
print(X_trans)
# Out:
# Shape of transformed features set: (80, 465)
# [[-0.02781221  0.37395233 -0.4289214  ...  0.          0.75955556
#    0.        ]
#  [ 2.50431022 -1.38644649 -0.47986463 ... -0.51612903 -0.52610857
#    0.        ]
#  [-0.60204699  0.28110298 -0.49685153 ...  0.58064516 -0.08775867
#    0.        ]
#  ...
#  [-0.03223295  0.21779093  1.03590393 ...  0.12903226 -0.17805529
#    0.        ]
#  [ 0.03396281  0.87459106  0.53517467 ...  0.29032258  0.28421459
#    0.        ]
#  [ 0.86164048  0.3813055  -0.59146288 ... -0.16129032 -0.20782888
#    0.        ]]

# %%
# #transform "Wafers" features

# X_trans=preprocessing_pipeline.fit_transform(X)
# print("shape of transformed features set:", X_trans.shape)

# X_trans

# %%
# %pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# from imblearn.combine import SMOTEomek

# X,y=X_trans[:,:-1],y
# resampler=SMOTEomek(sampling_strategy="auto")
# X_res,y_res=resampler.fit_resample(X,y)


from imblearn.combine import SMOTETomek  # Use SMOTETomek if SMOTEomek is not available

X, y = X_trans, y  # Ensure X_trans and y are correctly assigned

resampler = SMOTETomek(sampling_strategy="auto")
X_res, y_res = resampler.fit_resample(X, y)

print("Resampled feature set shape:", np.c_[X,y].shape)
print("Resampled labels shape:",np.c_[X_res,y_res].shape)
# Out:
# Resampled feature set shape: (80, 466)
# Resampled labels shape: (148, 466)

# %%
# target cats after resampling


print(np.unique(y_res))
print(f"value Counts: \n-1 :{len(y_res[y_res==-1])},1:{len(y_res[y_res==1])}")
# Out:
# [-1  1]
# value Counts:
# -1 :148,1:148

# %%
## prepare the test set


from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_res,y_res,test_size=1/3,random_state=42)

print(f"train set:{X_train.shape,y_train.shape}")
print(f"test set:{X_test.shape,y_test.shape}")
# Out:
# train set:((98, 465), (98, 1))
# test set:((50, 465), (50, 1))
